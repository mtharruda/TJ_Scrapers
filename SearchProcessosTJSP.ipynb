# %% [markdown]
# # Quais deputados se autobeneficiaram ao votar a favor da lei de improbidade administrativa
# O código vai buscar informações, via API da Câmara dos Deputados, da votação do PL n° 2505, de 2021 - sob ID DE VOTAÇÃO: 2184458-184. <br>
# Na 2ª etapa, iremos automatizar searchs no e-SAJ do TJ de todos os estados brasileiros e raspar as informações para análise posterior.
# ## Preparando o ambiente
# Para a raspagem dos dados, utilizaremos as bibliotecas Selenium. Para a análise, utilizaremos o Pandas.
# Já para a representação dos dados utilizaremos o matplotlib e Seaborn.

# %%
#Biblioteca para raspagem 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By

#Bibliotecas para várias funções relacionadas à tempo
import time
from datetime import datetime

#Bibliotecas para análise dos dados
import pandas as pd 
import numpy as np 
import requests as requests
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Conexão API Câmara dos Deputados

# %%
#Vamos criar nosso cabeçalho para aceitar as requisiões em json
headers = {
    "Accept": "Application/json"
}

# %% [markdown]
# ### Identificar os id's da PL

# %%
votos_pl = requests.get('https://dadosabertos.camara.leg.br/api/v2/proposicoes/2184458/votacoes?ordem=DESC&ordenarPor=dataHoraRegistro', headers=headers)
votos_pl = votos_pl.json()

votos_pl = pd.json_normalize(votos_pl['dados'])
votos_pl.head(6)
# Out:
#             id  \
# 0  2184458-186
# 1  2184458-184
# 2  2184458-172
# 3  2184458-169
# 4  2184458-161
# 5    2301348-3
#
#                                                               uri        data  \
# 0  https://dadosabertos.camara.leg.br/api/v2/votacoes/2184458-186  2021-10-06
# 1  https://dadosabertos.camara.leg.br/api/v2/votacoes/2184458-184  2021-10-06
# 2  https://dadosabertos.camara.leg.br/api/v2/votacoes/2184458-172  2021-10-05
# 3  https://dadosabertos.camara.leg.br/api/v2/votacoes/2184458-169  2021-10-05
# 4  https://dadosabertos.camara.leg.br/api/v2/votacoes/2184458-161  2021-10-05
# 5    https://dadosabertos.camara.leg.br/api/v2/votacoes/2301348-3  2021-10-05
#
#       dataHoraRegistro siglaOrgao  \
# 0  2021-10-06T16:58:25       PLEN
# 1  2021-10-06T16:57:25       PLEN
# 2  2021-10-05T20:05:40       PLEN
# 3  2021-10-05T19:47:45       PLEN
# 4  2021-10-05T18:34:35       PLEN
# 5  2021-10-05T13:23:52        CPD
#
#                                                   uriOrgao  \
# 0     https://dadosabertos.camara.leg.br/api/v2/orgaos/180
# 1     https://dadosabertos.camara.leg.br/api/v2/orgaos/180
# 2     https://dadosabertos.camara.leg.br/api/v2/orgaos/180
# 3     https://dadosabertos.camara.leg.br/api/v2/orgaos/180
# 4     https://dadosabertos.camara.leg.br/api/v2/orgaos/180
# 5  https://dadosabertos.camara.leg.br/api/v2/orgaos/537480
#
#                                                  uriEvento proposicaoObjeto  \
# 0  https://dadosabertos.camara.leg.br/api/v2/eventos/63505             None
# 1  https://dadosabertos.camara.leg.br/api/v2/eventos/63505             None
# 2  https://dadosabertos.camara.leg.br/api/v2/eventos/63472             None
# 3  https://dadosabertos.camara.leg.br/api/v2/eventos/63472             None
# 4  https://dadosabertos.camara.leg.br/api/v2/eventos/63472             None
# 5  https://dadosabertos.camara.leg.br/api/v2/eventos/63437  REQ 76/2021 CPD
#
#                                              uriProposicaoObjeto  \
# 0                                                           None
# 1                                                           None
# 2                                                           None
# 3                                                           None
# 4                                                           None
# 5  https://dadosabertos.camara.leg.br/api/v2/proposicoes/2301348
#
#                                                                                                                                                                      descricao  \
# 0                                                                                               Aprovada a Redação Final assinada pelo Relator, Dep. Carlos Zarattini (PT-SP).
# 1                                                                                      Aprovada a Emenda do Senado Federal nº 8. Sim: 287; não: 133; abstenção: 2; total: 422.
# 2                       Rejeitada a Emenda do Senado Federal nº 4 ao Projeto de Lei nº 2.505, de 2021, ressalvados os destaques. Sim: 162; não: 253; abstenção: 4; total: 419.
# 3  Aprovadas as Emendas do Senado Federal nºs 1, 2, 3, 5, 6, 7 e 8 ao Projeto de Lei nº 2.505, de 2021, ressalvados os destaques. Sim: 395; não: 22; abstenção: 3; total: 420.
# 4                                                                                                                     Rejeitado o Requerimento. Sim: 60; não: 346; total: 406.
# 5                                                                                                                                                                    Aprovado.
#
#    aprovacao
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        0.0
# 5        1.0

# %% [markdown]
# ### Lista votos

# %%
lista_votos = requests.get('https://dadosabertos.camara.leg.br/api/v2/votacoes/2184458-184/votos', headers=headers)
lista_votos = lista_votos.json()

lista_votos = pd.json_normalize(lista_votos['dados'])
lista_votos
# Out:
#       tipoVoto     dataRegistroVoto  deputado_.id  \
# 0          Sim  2021-10-06T16:55:06         74352
# 1          Sim  2021-10-06T16:54:47         74366
# 2          Sim  2021-10-06T16:54:10        204553
# 3          Não  2021-10-06T16:54:02        141553
# 4          Não  2021-10-06T16:53:57        204363
# ..         ...                  ...           ...
# 418        Não  2021-10-06T16:45:03        204548
# 419        Sim  2021-10-06T16:45:01         76874
# 420        Sim  2021-10-06T16:45:01        160556
# 421        Sim  2021-10-06T16:44:59         73801
# 422  Artigo 17  2021-10-06T16:44:47        204556
#
#                                                   deputado_.uri  \
# 0     https://dadosabertos.camara.leg.br/api/v2/deputados/74352
# 1     https://dadosabertos.camara.leg.br/api/v2/deputados/74366
# 2    https://dadosabertos.camara.leg.br/api/v2/deputados/204553
# 3    https://dadosabertos.camara.leg.br/api/v2/deputados/141553
# 4    https://dadosabertos.camara.leg.br/api/v2/deputados/204363
# ..                                                          ...
# 418  https://dadosabertos.camara.leg.br/api/v2/deputados/204548
# 419   https://dadosabertos.camara.leg.br/api/v2/deputados/76874
# 420  https://dadosabertos.camara.leg.br/api/v2/deputados/160556
# 421   https://dadosabertos.camara.leg.br/api/v2/deputados/73801
# 422  https://dadosabertos.camara.leg.br/api/v2/deputados/204556
#
#                deputado_.nome deputado_.siglaPartido  \
# 0                Nilson Pinto                   PSDB
# 1                 João Campos           REPUBLICANOS
# 2    Pastor Sargento Isidório                 AVANTE
# 3            Vanderlei Macris                   PSDB
# 4               Osires Damaso                    PSC
# ..                        ...                    ...
# 418             Heitor Freire                    PSL
# 419            Marcelo Freixo                    PSB
# 420                Padre João                     PT
# 421         Renildo Calheiros                  PCdoB
# 422             Marcelo Ramos                     PL
#
#                                          deputado_.uriPartido  \
# 0    https://dadosabertos.camara.leg.br/api/v2/partidos/36835
# 1    https://dadosabertos.camara.leg.br/api/v2/partidos/37908
# 2    https://dadosabertos.camara.leg.br/api/v2/partidos/36898
# 3    https://dadosabertos.camara.leg.br/api/v2/partidos/36835
# 4    https://dadosabertos.camara.leg.br/api/v2/partidos/36833
# ..                                                        ...
# 418  https://dadosabertos.camara.leg.br/api/v2/partidos/36837
# 419  https://dadosabertos.camara.leg.br/api/v2/partidos/36832
# 420  https://dadosabertos.camara.leg.br/api/v2/partidos/36844
# 421  https://dadosabertos.camara.leg.br/api/v2/partidos/36779
# 422  https://dadosabertos.camara.leg.br/api/v2/partidos/37906
#
#     deputado_.siglaUf  deputado_.idLegislatura  \
# 0                  PA                       56
# 1                  GO                       56
# 2                  BA                       56
# 3                  SP                       56
# 4                  TO                       56
# ..                ...                      ...
# 418                CE                       56
# 419                RJ                       56
# 420                MG                       56
# 421                PE                       56
# 422                AM                       56
#
#                                                  deputado_.urlFoto  \
# 0     https://www.camara.leg.br/internet/deputado/bandep/74352.jpg
# 1     https://www.camara.leg.br/internet/deputado/bandep/74366.jpg
# 2    https://www.camara.leg.br/internet/deputado/bandep/204553.jpg
# 3    https://www.camara.leg.br/internet/deputado/bandep/141553.jpg
# 4    https://www.camara.leg.br/internet/deputado/bandep/204363.jpg
# ..                                                             ...
# 418  https://www.camara.leg.br/internet/deputado/bandep/204548.jpg
# 419   https://www.camara.leg.br/internet/deputado/bandep/76874.jpg
# 420  https://www.camara.leg.br/internet/deputado/bandep/160556.jpg
# 421   https://www.camara.leg.br/internet/deputado/bandep/73801.jpg
# 422  https://www.camara.leg.br/internet/deputado/bandep/204556.jpg
#
#                               deputado_.email
# 0                                        None
# 1                                        None
# 2    dep.pastorsargentoisidorio@camara.leg.br
# 3                                        None
# 4                                        None
# ..                                        ...
# 418                                      None
# 419                                      None
# 420               dep.padrejoao@camara.leg.br
# 421        dep.renildocalheiros@camara.leg.br
# 422                                      None
#
# [423 rows x 11 columns]

# %% [markdown]
# ### Informações adicionais dos deputados

# %%
nome_deputado = []

for i, row in lista_votos.iterrows():
    deputado_id = row['deputado_.id']
    deputados_infos = requests.get(f'https://dadosabertos.camara.leg.br/api/v2/deputados/{deputado_id}')
    deputados_infos = deputados_infos.json()
    nome_deputado.append(deputados_infos['dados']['nomeCivil'])
    print(deputado_id)

lista_votos['NomeCivilDeputado'] = nome_deputado
# Out:
# 74352
# 74366
# 204553
# 141553
# 204363
# 160758
# 204505
# 178934
# 178884
# 217480
# 204547
# 204414
# 178896
# 178927
# 204364
# 204387
# 204531
# 160592
# 141516
# 204473
# 178996
# 204482
# 160591
# 204395
# 141513
# 141458
# 178986
# 141434
# 157130
# 204559
# 160976
# 196358
# 178937
# 178956
# 204527
# 74090
# 204398
# 204428
# 141459
# 74317
# 204377
# 204515
# 178933
# 73692
# 204539
# 160610
# 198783
# 204392
# 74376
# 166402
# 160553
# 179001
# 74537
# 74253
# 160527
# 217330
# 74439
# 178910
# 74646
# 204571
# 73486
# 74052
# 209189
# 204449
# 204431
# 178964
# 178921
# 204488
# 66179
# 90201
# 204386
# 74159
# 197438
# 178970
# 204534
# 164359
# 160601
# 178985
# 178912
# 74158
# 204511
# 204360
# 204408
# 204475
# 73466
# 74419
# 178873
# 160528
# 204461
# 146788
# 74784
# 92346
# 204430
# 205865
# 74057
# 204468
# 73586
# 132504
# 141398
# 204546
# 204573
# 206231
# 74848
# 204394
# 204404
# 204514
# 204572
# 178858
# 178972
# 204548
# 76874
# 160556
# 73801
# 204556

# %%
lista_votos.query('`deputado_.nome`.str.contains("Passos")')
# Out:
#     tipoVoto     dataRegistroVoto  deputado_.id  \
# 328      Sim  2021-10-06T16:45:41        178981
#
#                                                   deputado_.uri  \
# 328  https://dadosabertos.camara.leg.br/api/v2/deputados/178981
#
#        deputado_.nome deputado_.siglaPartido  \
# 328  Herculano Passos                    MDB
#
#                                          deputado_.uriPartido  \
# 328  https://dadosabertos.camara.leg.br/api/v2/partidos/36899
#
#     deputado_.siglaUf  deputado_.idLegislatura  \
# 328                SP                       56
#
#                                                  deputado_.urlFoto  \
# 328  https://www.camara.leg.br/internet/deputado/bandep/178981.jpg
#
#     deputado_.email                 NomeCivilDeputado
# 328            None  HERCULANO CASTILHO PASSOS JUNIOR

# %%
lista_votos.query('tipoVoto == "Sim"')['deputado_.siglaUf'].value_counts()
# Out:
# deputado_.siglaUf
# MG    32
# SP    29
# BA    28
# RJ    20
# RS    19
# PE    17
# PR    15
# CE    12
# MA    11
# GO     9
# PA     9
# PI     8
# AC     8
# SE     7
# TO     6
# AP     6
# RN     6
# AL     6
# SC     6
# PB     6
# RR     5
# DF     4
# MS     4
# MT     4
# RO     4
# ES     3
# AM     3
# Name: count, dtype: int64

# %% [markdown]
# # Inicialização do raspador

# %%
teste_processo = [] 
teste_classe = []
teste_assunto = []

driver = webdriver.Chrome()
driver.get('https://esaj.tjsp.jus.br/cpopg/open.do')
WebDriverWait(driver, 5)

driver.maximize_window() 
driver.implicitly_wait(5) 

botao = driver.find_element(By.ID, "cbPesquisa")
select = Select(botao)
select.select_by_index(1)


driver.find_element(By.ID, "campo_NMPARTE").send_keys("HERCULANO CASTILHO PASSOS JUNIOR")
driver.find_element(By.ID, "pesquisarPorNomeCompleto").click()
driver.find_element(By.ID, "botaoConsultarProcessos").click()
driver.find_element(By.ID, "contadorDeProcessos").text

WebDriverWait(driver, 5)

lista_processo = driver.find_elements(By.CLASS_NAME, "linkProcesso")
classe_processo = driver.find_elements(By.CLASS_NAME, "classeProcesso")
assunto_processo = driver.find_elements(By.CLASS_NAME, "assuntoPrincipalProcesso")

count = 1
for i in lista_processo: 
    print(count,
          i.text)
    count +=1
    teste_processo.append(i.text)

for p in classe_processo:
    teste_classe.append(p.text)

for a in assunto_processo:
    teste_assunto.append(a.text)

try:
    botao = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/ul/li[2]/a')
    botao.click()
    
    count = 1
    for i in lista_processo: 
        print(count,
              i.text)
        count +=1
        teste_processo.append(i.text)
        
        for p in classe_processo:
            teste_classe.append(p.text)
            
        for p in classe_processo:
            teste_classe.append(p.text)
        
        for a in assunto_processo:
            teste_assunto.append(a.text)
    
except NoSuchElementException:
    print("Apenas uma página")

WebDriverWait(driver, 5)
# Out:
# 1 1011194-58.2024.8.26.0286
# 2 1008554-82.2024.8.26.0286
# 3 1007967-60.2024.8.26.0286
# 4 1000795-67.2024.8.26.0286
# 5 1506372-03.2023.8.26.0286
# 6 1506371-18.2023.8.26.0286
# 7 1506370-33.2023.8.26.0286
# 8 1507128-80.2021.8.26.0286
# 9 1007909-62.2021.8.26.0286
# 10 1008243-33.2020.8.26.0286
# 11 1006055-67.2020.8.26.0286
# 12 1000498-02.2020.8.26.0286
# 13 1010456-17.2017.8.26.0286
# 14 1503768-79.2017.8.26.0286
# 15 1003632-76.2016.8.26.0286
# 16 1003176-29.2016.8.26.0286
# 17 1000406-63.2016.8.26.0286
# 18 1002493-60.2014.8.26.0286
# 19 0012415-16.2012.8.26.0286
# 20 0006240-06.2012.8.26.0286
# 21 0010357-74.2011.8.26.0286
# 22 0005113-67.2011.8.26.0286
# 23 0004743-88.2011.8.26.0286
# 24 0014629-53.2007.8.26.0286
# 25 0013431-78.2007.8.26.0286
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[9], line 48
#      45 count = 1
#      46 for i in lista_processo:
#      47     print(count,
# ---> 48           i.text)
#      49     count +=1
#      50     teste_processo.append(i.text)
#
# File c:\Users\matheus.arruda\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File c:\Users\matheus.arruda\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\matheus.arruda\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
#     385     response["value"] = self._unwrap_value(response.get("value", None))
#     386     return response
#
# File c:\Users\matheus.arruda\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=132.0.6834.197); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF697DF02F5+28725]
# 	(No symbol) [0x00007FF697D52AE0]
# 	(No symbol) [0x00007FF697BE510A]
# 	(No symbol) [0x00007FF697BF98C4]
# 	(No symbol) [0x00007FF697BF83D1]
# 	(No symbol) [0x00007FF697BECA89]
# 	(No symbol) [0x00007FF697BEA7E2]
# 	(No symbol) [0x00007FF697BEEABC]
# 	(No symbol) [0x00007FF697BEEB8F]
# 	(No symbol) [0x00007FF697C3313F]
# 	(No symbol) [0x00007FF697C5FFAA]
# 	(No symbol) [0x00007FF697C2BF86]
# 	(No symbol) [0x00007FF697C601C0]
# 	(No symbol) [0x00007FF697C80181]
# 	(No symbol) [0x00007FF697C5FD53]
# 215  https://dadosabertos.camara.leg.br/api/v2/deputados/160558
# 251  https://dadosabertos.camara.leg.br/api/v2/deputados/152610
# 253  https://dadosabertos.camara.leg.br/api/v2/deputados/204503
# 277   https://dadosabertos.camara.leg.br/api/v2/deputados/73433
# 289  https://dadosabertos.camara.leg.br/api/v2/deputados/204504
# 308  https://dadosabertos.camara.leg.br/api/v2/deputados/178987
# 314   https://dadosabertos.camara.leg.br/api/v2/deputados/74283
# 317  https://dadosabertos.camara.leg.br/api/v2/deputados/178977
# 328  https://dadosabertos.camara.leg.br/api/v2/deputados/178981
# 329  https://dadosabertos.camara.leg.br/api/v2/deputados/178983
# 334  https://dadosabertos.camara.leg.br/api/v2/deputados/160655
# 342  https://dadosabertos.camara.leg.br/api/v2/deputados/204540
# 354   https://dadosabertos.camara.leg.br/api/v2/deputados/66828
# 355   https://dadosabertos.camara.leg.br/api/v2/deputados/73531
# 361  https://dadosabertos.camara.leg.br/api/v2/deputados/204501
# 399   https://dadosabertos.camara.leg.br/api/v2/deputados/74784
# 407  https://dadosabertos.camara.leg.br/api/v2/deputados/141398
#
#            deputado_.nome deputado_.siglaPartido  \
# 26            Nilto Tatto                     PT
# 30               Tiririca                     PL
# 34        Geninho Zuliani                    DEM
# 76    Pr. Marco Feliciano                     PL
# 80           David Soares                    DEM
# 100            Rui Falcão                     PT
# 121         Enrico Misasi                     PV
# 122     Luiz Carlos Motta                     PL
# 147   Henrique do Paraíso           REPUBLICANOS
# 163      Celso Russomanno           REPUBLICANOS
# 189        Paulo Teixeira                     PT
# 207     Vinicius Carvalho           REPUBLICANOS
# 215    Paulo Freire Costa                     PL
# 251         Roberto Alves           REPUBLICANOS
# 253     Alexandre Padilha                     PT
# 277     Arlindo Chinaglia                     PT
# 289  Cezinha de Madureira                    PSD
# 308         Orlando Silva                  PCdoB
# 314            Vicentinho                     PT
# 317          Eduardo Cury                   PSDB
# 328      Herculano Passos                    MDB
# 329         Marcio Alvino                     PL
# 334          Ricardo Izar                     PP
# 342           Maria Rosas           REPUBLICANOS
# 354         Fausto Pinato                     PP
# 355          Ivan Valente                   PSOL
# 361       Alencar Santana                     PT
# 399        Luiza Erundina                   PSOL
# 407      Carlos Zarattini                     PT
#
#                                          deputado_.uriPartido  \
# 26   https://dadosabertos.camara.leg.br/api/v2/partidos/36844
# 30   https://dadosabertos.camara.leg.br/api/v2/partidos/37906
# 34   https://dadosabertos.camara.leg.br/api/v2/partidos/36769
# 76   https://dadosabertos.camara.leg.br/api/v2/partidos/37906
# 80   https://dadosabertos.camara.leg.br/api/v2/partidos/36769
# 100  https://dadosabertos.camara.leg.br/api/v2/partidos/36844
# 121  https://dadosabertos.camara.leg.br/api/v2/partidos/36851
# 122  https://dadosabertos.camara.leg.br/api/v2/partidos/37906
# 147  https://dadosabertos.camara.leg.br/api/v2/partidos/37908
# 163  https://dadosabertos.camara.leg.br/api/v2/partidos/37908
# 189  https://dadosabertos.camara.leg.br/api/v2/partidos/36844
# 207  https://dadosabertos.camara.leg.br/api/v2/partidos/37908
# 215  https://dadosabertos.camara.leg.br/api/v2/partidos/37906
# 251  https://dadosabertos.camara.leg.br/api/v2/partidos/37908
# 253  https://dadosabertos.camara.leg.br/api/v2/partidos/36844
# 277  https://dadosabertos.camara.leg.br/api/v2/partidos/36844
# 289  https://dadosabertos.camara.leg.br/api/v2/partidos/36834
# 308  https://dadosabertos.camara.leg.br/api/v2/partidos/36779
# 314  https://dadosabertos.camara.leg.br/api/v2/partidos/36844
#
# 407  https://www.camara.leg.br/internet/deputado/bandep/141398.jpg
#
#                           deputado_.email  \
# 26           dep.niltotatto@camara.leg.br
# 30             dep.tiririca@camara.leg.br
# 34                                   None
# 76    dep.pr.marcofeliciano@camara.leg.br
# 80          dep.davidsoares@camara.leg.br
# 100           dep.ruifalcao@camara.leg.br
# 121                                  None
# 122     dep.luizcarlosmotta@camara.leg.br
# 147                                  None
# 163     dep.celsorussomanno@camara.leg.br
# 189                                  None
# 207    dep.viniciuscarvalho@camara.leg.br
# 215    dep.paulofreirecosta@camara.leg.br
# 251                                  None
# 253                                  None
# 277    dep.arlindochinaglia@camara.leg.br
# 289  dep.cezinhademadureira@camara.leg.br
# 308        dep.orlandosilva@camara.leg.br
# 314          dep.vicentinho@camara.leg.br
# 317                                  None
# 328                                  None
# 329        dep.marcioalvino@camara.leg.br
# 334                                  None
# 342          dep.mariarosas@camara.leg.br
# 354        dep.faustopinato@camara.leg.br
# 355         dep.ivanvalente@camara.leg.br
# 361      dep.alencarsantana@camara.leg.br
# 399       dep.luizaerundina@camara.leg.br
# 407     dep.carloszarattini@camara.leg.br
#
#                               NomeCivilDeputado
# 26                          NILTO IGNACIO TATTO
# 30   FRANCISCO EVERARDO TIRIRICA OLIVEIRA SILVA
# 34                         EUGENIO JOSÉ ZULIANI
# 76                      MARCO ANTÔNIO FELICIANO
# 80                 DAVID BEZERRA RIBEIRO SOARES
# 100                  RUI GOETHE DA COSTA FALCÃO
# 121         ENRICO VAN BLARCUM DE GRAAFF MISASI
# 122                           LUIZ CARLOS MOTTA
# 147                     HENRIQUE STEIN SCIASCIO
# 163                  CELSO UBIRAJARA RUSSOMANNO
# 189                LUIZ PAULO TEIXEIRA FERREIRA
# 207                 VINICIUS RAPOZO DE CARVALHO
# 215               PAULO ROBERTO FREIRE DA COSTA
# 251             BENEDITO ROBERTO ALVES FERREIRA
# 253              ALEXANDRE ROCHA SANTOS PADILHA
# 277                    ARLINDO CHIGNALIA JUNIOR
# 289                ANTONIO CEZAR CORREIA FREIRE
# 308               ORLANDO SILVA DE JESUS JUNIOR
# 314                      VICENTE PAULO DA SILVA
# 317                        EDUARDO PEDROSA CURY
# 328            HERCULANO CASTILHO PASSOS JUNIOR
# 329                 MARCIO LUIZ ALVINO DE SOUZA
# 334                         RICARDO IZAR JUNIOR
# 342                 MARIA DO PARTO MENDES ROSAS
# 354                           FAUSTO RUY PINATO
# 355                                IVAN VALENTE
# 361                       ALENCAR SANTANA BRAGA
# 399                     LUIZA ERUNDINA DE SOUSA
# 407              CARLOS ALBERTO ROLIM ZARATTINI

# %%
driver = webdriver.Chrome()
driver.get('https://esaj.tjsp.jus.br/cpopg/open.do')
driver.maximize_window()

# --- LISTAS PARA ARMAZENAR DADOS ---
nome_deputados_lista = []
partidos_lista = []
num_processos_lista = []
classeprocesso_lista = []
assuntoprocesso_lista = []

def realizar_pesquisa(driver, nome_deputado):
    """Realiza a pesquisa por nome completo no site."""
    try:
        botao_tipo_pesquisa = driver.find_element(By.ID, "cbPesquisa")
        select_tipo_pesquisa = Select(botao_tipo_pesquisa)
        select_tipo_pesquisa.select_by_index(1)  # Seleciona para pesquisar por NOME

        campo_nome = driver.find_element(By.ID, "campo_NMPARTE")
        campo_nome.clear()
        campo_nome.send_keys(nome_deputado)
        
        driver.implicitly_wait(15)
        
        driver.find_element(By.ID, "pesquisarPorNomeCompleto").click() #Seleciona a caixa para pesquisar por nome completo
        
        driver.implicitly_wait(10)

        driver.find_element(By.ID, "botaoConsultarProcessos").click() #Clica no botão para pesquisar
        
    except NoSuchElementException:
        print(f"Erro ao realizar pesquisa para {nome_deputado}")
        return False  # Indica falha na pesquisa
    return True # Indica sucesso na pesquisa


def extrair_dados_da_tabela(driver, nome_deputado, partido_deputado):
    """Extrai dados da tabela de processos, se presente."""
    nome_lista_temp = []
    partidos_lista_temp = []
    num_processos_lista_temp = []
    classeprocesso_lista_temp = []
    assuntoprocesso_lista_temp = []

    try:
        lista_processo_elementos = driver.find_elements(By.CLASS_NAME, "linkProcesso")
        classe_processo_elementos = driver.find_elements(By.CLASS_NAME, "classeProcesso")
        assunto_processo_elementos = driver.find_elements(By.CLASS_NAME, "assuntoPrincipalProcesso")

        if not lista_processo_elementos: # Verifica se encontrou processos
            print(f"Nenhum processo encontrado na tabela para {nome_deputado}")
            return [], [], [], [], []

        for i in range(len(lista_processo_elementos)):
            nome_lista_temp.append(nome_deputado)
            partidos_lista_temp.append(partido_deputado)
            num_processos_lista_temp.append(lista_processo_elementos[i].text)
            classeprocesso_lista_temp.append(classe_processo_elementos[i].text)
            assuntoprocesso_lista_temp.append(assunto_processo_elementos[i].text)

    except NoSuchElementException:
        print(f"Erro ao extrair dados da tabela para {nome_deputado}")
        return [], [], [], [], [] # Retorna listas vazias em caso de erro

    return nome_lista_temp, partidos_lista_temp, num_processos_lista_temp, classeprocesso_lista_temp, assuntoprocesso_lista_temp


def extrair_detalhes_processo(driver, nome_deputado, partido_deputado):
    """Extrai detalhes do processo se estiver na página 'show.do?'."""
    try:
        nprocesso = driver.find_element(By.ID, "numeroProcesso").text
        processo_clase = driver.find_element(By.ID, "labelClasseProcesso").text
        processo_assunto = driver.find_element(By.ID, "assuntoProcesso").text

        nome_deputados_lista.append(nome_deputado)
        partidos_lista.append(partido_deputado)
        num_processos_lista.append(nprocesso)
        classeprocesso_lista.append(processo_clase)
        assuntoprocesso_lista.append(processo_assunto)

    except NoSuchElementException:
        print(f"Erro ao extrair detalhes do processo para {nome_deputado}")


def voltar_para_pesquisa(driver):
    """Limpa o campo de pesquisa para a próxima busca."""
    try:
        campo_nome = driver.find_element(By.ID, "campo_NMPARTE")
        campo_nome.clear()

        time.sleep(10)
        
    except NoSuchElementException:
        print("Erro ao limpar campo de pesquisa.")


# --- LOOP PRINCIPAL ---
for i, row in bd_deputados_sp.iterrows():  
    nome_deputado = row['NomeCivilDeputado']
    partido_deputado = row['deputado_.siglaPartido']

    print(f"Pesquisando por: {nome_deputado} ({partido_deputado})")

    if realizar_pesquisa(driver, nome_deputado): # Realiza pesquisa e verifica sucesso
        url = driver.current_url
        if "show.do?" in str(url):
            extrair_detalhes_processo(driver, nome_deputado, partido_deputado)
            try:
                driver.find_element(By.CLASS_NAME, 'unj-link-back').click() # Voltar para lista
            except NoSuchElementException:
                print("Erro ao clicar em 'Voltar' para lista de processos.")

        else: # Página de lista de processos (ou "nenhum processo encontrado")
            n, pa, np, cp, ap = extrair_dados_da_tabela(driver, nome_deputado, partido_deputado)
            nome_deputados_lista.extend(n)
            partidos_lista.extend(pa)
            num_processos_lista.extend(np)
            classeprocesso_lista.extend(cp)
            assuntoprocesso_lista.extend(ap)

        voltar_para_pesquisa(driver) # Limpa campo para próxima pesquisa
    else:
        print(f"Falha na pesquisa inicial para {nome_deputado}. Pulando para o próximo deputado.")

driver.quit()
# Out:
# Pesquisando por: NILTO IGNACIO TATTO (PT)
# Nenhum processo encontrado na tabela para NILTO IGNACIO TATTO
# Pesquisando por: FRANCISCO EVERARDO TIRIRICA OLIVEIRA SILVA (PL)
# Nenhum processo encontrado na tabela para FRANCISCO EVERARDO TIRIRICA OLIVEIRA SILVA
# Pesquisando por: EUGENIO JOSÉ ZULIANI (DEM)
# Pesquisando por: MARCO ANTÔNIO FELICIANO (PL)
# Pesquisando por: DAVID BEZERRA RIBEIRO SOARES (DEM)
# Pesquisando por: RUI GOETHE DA COSTA FALCÃO (PT)
# Nenhum processo encontrado na tabela para RUI GOETHE DA COSTA FALCÃO
# Pesquisando por: ENRICO VAN BLARCUM DE GRAAFF MISASI (PV)
# Pesquisando por: LUIZ CARLOS MOTTA (PL)
# Pesquisando por: HENRIQUE STEIN SCIASCIO (REPUBLICANOS)
# Pesquisando por: CELSO UBIRAJARA RUSSOMANNO (REPUBLICANOS)
# Pesquisando por: LUIZ PAULO TEIXEIRA FERREIRA (PT)
# Pesquisando por: VINICIUS RAPOZO DE CARVALHO (REPUBLICANOS)
# Nenhum processo encontrado na tabela para VINICIUS RAPOZO DE CARVALHO
# Pesquisando por: PAULO ROBERTO FREIRE DA COSTA (PL)
# Pesquisando por: BENEDITO ROBERTO ALVES FERREIRA (REPUBLICANOS)
# Pesquisando por: ALEXANDRE ROCHA SANTOS PADILHA (PT)
# Pesquisando por: ARLINDO CHIGNALIA JUNIOR (PT)
# Pesquisando por: ANTONIO CEZAR CORREIA FREIRE (PSD)
# Pesquisando por: ORLANDO SILVA DE JESUS JUNIOR (PCdoB)
# Pesquisando por: VICENTE PAULO DA SILVA (PT)
# Pesquisando por: EDUARDO PEDROSA CURY (PSDB)
# Pesquisando por: HERCULANO CASTILHO PASSOS JUNIOR (MDB)
# Pesquisando por: MARCIO LUIZ ALVINO DE SOUZA (PL)
# Nenhum processo encontrado na tabela para MARCIO LUIZ ALVINO DE SOUZA
# Pesquisando por: RICARDO IZAR JUNIOR (PP)
# Pesquisando por: MARIA DO PARTO MENDES ROSAS (REPUBLICANOS)
# Nenhum processo encontrado na tabela para MARIA DO PARTO MENDES ROSAS
# Pesquisando por: FAUSTO RUY PINATO (PP)
# Pesquisando por: IVAN VALENTE (PSOL)
# Pesquisando por: ALENCAR SANTANA BRAGA (PT)
# Pesquisando por: LUIZA ERUNDINA DE SOUSA (PSOL)
# Pesquisando por: CARLOS ALBERTO ROLIM ZARATTINI (PT)

# %%
data = {'Nome':nome_deputados_lista, 'Partido':partidos_lista, 'Processo':num_processos_lista, 'Classe':classeprocesso_lista, 'Assunto':assuntoprocesso_lista}

bd_teste = pd.DataFrame(data)

bd_teste
# Out:
#                                Nome Partido                   Processo  \
# 0              EUGENIO JOSÉ ZULIANI     DEM  1037674-83.2023.8.26.0100
# 1              EUGENIO JOSÉ ZULIANI     DEM  1000297-15.2025.8.26.0066
# 2              EUGENIO JOSÉ ZULIANI     DEM  1000426-85.2025.8.26.0400
# 3              EUGENIO JOSÉ ZULIANI     DEM  1001882-07.2024.8.26.0400
# 4              EUGENIO JOSÉ ZULIANI     DEM  1001632-71.2024.8.26.0400
# ..                              ...     ...                        ...
# 187         LUIZA ERUNDINA DE SOUSA    PSOL  0728959-30.1990.8.26.0053
# 188         LUIZA ERUNDINA DE SOUSA    PSOL  0707367-61.1989.8.26.0053
# 189  CARLOS ALBERTO ROLIM ZARATTINI      PT  0007357-67.2003.8.26.0053
# 190  CARLOS ALBERTO ROLIM ZARATTINI      PT  0418437-07.1996.8.26.0053
# 191  CARLOS ALBERTO ROLIM ZARATTINI      PT  0091077-82.2003.8.26.0100
#
#                                                                      Classe  \
# 0                                                  Procedimento Comum Cível
# 1                                                              Ação Popular
# 2                                                Mandado de Segurança Cível
# 3                                    Procedimento do Juizado Especial Cível
# 4    Crimes de Calúnia, Injúria e Difamação de Competência do Juiz Singular
# ..                                                                      ...
# 187                                                            Ação Popular
# 188                                                            Ação Popular
# 189                                                            Ação Popular
# 190                                                 Cumprimento de sentença
# 191                                                Procedimento Comum Cível
#
#                                     Assunto
# 0    DIREITO PROCESSUAL CIVIL E DO TRABALHO
# 1                      Atos Administrativos
# 2                 Concurso Público / Edital
# 3                Indenização por Dano Moral
# 4                                   Simples
# ..                                      ...
# 187
# 188                    Atos Administrativos
# 189             Utilização de bens públicos
# 190              Improbidade Administrativa
# 191              Indenização por Dano Moral
#
# [192 rows x 5 columns]

# %%
bd_teste.query('Nome.str.contains("PASSOS")')
# Out:
#                                  Nome Partido                   Processo  \
# 144  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1011194-58.2024.8.26.0286
# 145  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1008554-82.2024.8.26.0286
# 146  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1007967-60.2024.8.26.0286
# 147  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1000795-67.2024.8.26.0286
# 148  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1506372-03.2023.8.26.0286
# 149  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1506371-18.2023.8.26.0286
# 150  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1506370-33.2023.8.26.0286
# 151  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1507128-80.2021.8.26.0286
# 152  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1007909-62.2021.8.26.0286
# 153  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1008243-33.2020.8.26.0286
# 154  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1006055-67.2020.8.26.0286
# 155  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1000498-02.2020.8.26.0286
# 156  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1010456-17.2017.8.26.0286
# 157  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1503768-79.2017.8.26.0286
# 158  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1003632-76.2016.8.26.0286
# 159  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1003176-29.2016.8.26.0286
# 160  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1000406-63.2016.8.26.0286
# 161  HERCULANO CASTILHO PASSOS JUNIOR     MDB  1002493-60.2014.8.26.0286
# 162  HERCULANO CASTILHO PASSOS JUNIOR     MDB  0012415-16.2012.8.26.0286
# 163  HERCULANO CASTILHO PASSOS JUNIOR     MDB  0006240-06.2012.8.26.0286
# 164  HERCULANO CASTILHO PASSOS JUNIOR     MDB  0010357-74.2011.8.26.0286
# 165  HERCULANO CASTILHO PASSOS JUNIOR     MDB  0005113-67.2011.8.26.0286
# 166  HERCULANO CASTILHO PASSOS JUNIOR     MDB  0004743-88.2011.8.26.0286
# 167  HERCULANO CASTILHO PASSOS JUNIOR     MDB  0014629-53.2007.8.26.0286
# 168  HERCULANO CASTILHO PASSOS JUNIOR     MDB  0013431-78.2007.8.26.0286
#
#                                                                      Classe  \
# 144                                              Mandado de Segurança Cível
# 145                                                Procedimento Comum Cível
# 146                                                Procedimento Comum Cível
# 147                                                Procedimento Comum Cível
# 148                                                         Execução Fiscal
# 149                                                         Execução Fiscal
# 150                                                         Execução Fiscal
# 151                                                         Execução Fiscal
# 152                                                      Ação Civil Pública
# 153                                                      Ação Civil Pública
# 154                                Ação Civil de Improbidade Administrativa
# 155                                                      Ação Civil Pública
# 156                                Ação Civil de Improbidade Administrativa
# 157                                                         Execução Fiscal
# 158                                Ação Civil de Improbidade Administrativa
# 159                                                      Ação Civil Pública
# 160                                                      Ação Civil Pública
# 161                                                      Ação Civil Pública
# 162  Crimes de Calúnia, Injúria e Difamação de Competência do Juiz Singular
# 163                                                      Ação Civil Pública
# 164                                Ação Civil de Improbidade Administrativa
# 165                                         Outros Feitos não Especificados
# 166                                                      Ação Civil Pública
# 167                                                            Ação Popular
# 168                                                      Ação Civil Pública
#
#                                         Assunto
# 144                   Garantias Constitucionais
# 145                  Indenização por Dano Moral
# 146                   Contratos Administrativos
# 147                  Indenização por Dano Moral
# 148  IPTU/ Imposto Predial e Territorial Urbano
# 149  IPTU/ Imposto Predial e Territorial Urbano
# 150  IPTU/ Imposto Predial e Territorial Urbano
# 151  IPTU/ Imposto Predial e Territorial Urbano
# 152                  Improbidade Administrativa
# 153                              Dano ao Erário
# 154                              Dano ao Erário
# 155                              Dano ao Erário
# 156                              Dano ao Erário
# 157  IPTU/ Imposto Predial e Territorial Urbano
# 158                  Improbidade Administrativa
# 159                  Improbidade Administrativa
# 160                  Improbidade Administrativa
# 161                  Improbidade Administrativa
# 162                                     Calúnia
# 163                  Improbidade Administrativa
# 164                        Atos Administrativos
# 165
# 166                  Improbidade Administrativa
# 167                        Atos Administrativos
# 168                  Improbidade Administrativa

# %%
bd_teste['Assunto'].value_counts()
# Out:
# Assunto
# Indenização por Dano Moral                                   26
#                                                              17
# Improbidade Administrativa                                   14
# IPTU/ Imposto Predial e Territorial Urbano                   11
# Dano ao Erário                                                8
#                                                              ..
# Sucessões                                                     1
# Crimes contra a Fé Pública                                    1
# Inexequibilidade do Título / Inexigibilidade da Obrigação     1
# Citação                                                       1
# Utilização de bens públicos                                   1
# Name: count, Length: 72, dtype: int64

# %%
bd_teste['AssuntoProcesso'].value_counts().nlargest(50)
# Out:
# AssuntoProcesso
# Indenização por Dano Moral                   27
# Gratificações de Atividade                   25
# Não Discriminação                            25
# DIREITO PROCESSUAL CIVIL E DO TRABALHO       14
#                                              12
# Violação aos Princípios Administrativos      12
# Antecipação de Tutela / Tutela Específica     6
# Prestação de Serviços                         5
# ISS/ Imposto sobre Serviços                   2
# Indenização por Dano Material                 1
# Name: count, dtype: int64
